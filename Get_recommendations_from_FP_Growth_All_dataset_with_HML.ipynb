# %%
import ast
import pandas as pd
import sys
import matplotlib.pylab as plt
import timeit

# %%
fp_growth_itemsets_file_location = './Dataset/frequent_itemsets_FP_growth_all_dataset_with_HML.txt'

# %%
fp_growth_itemsets_file = open(fp_growth_itemsets_file_location)
fp_growth_itemsets = []
for line in fp_growth_itemsets_file:
    itemset = line.strip().replace(']','').replace('[','').replace("'",'').replace(" ",'').split(',')
    fp_growth_itemsets.append(itemset)
    
fp_growth_itemsets_file.close()

# %%
fp_growth_itemsets[1:10]
# Out:
# [['14397L', '217471L'],
#  ['217471L', '91177L'],
#  ['14397L', '91177L'],
#  ['12985L', '288653L'],
#  ['25150L', '288653L'],
#  ['177172L', '54386L'],
#  ['177172L', '91177L'],
#  ['217471L', '54386L'],
#  ['54386L', '91177L']]

# %%
#Generate recommendations

songid = 14397

possible_songids = [str(songid)+'L', str(songid)+'M', str(songid)+'H']

recommendations_L = []
recommendations_M = []
recommendations_H = []

for itemset in fp_growth_itemsets:
    
    songid_exists_flag = (possible_songids[0] in itemset) or (possible_songids[1] in itemset) or (possible_songids[2] in itemset)
    
    if( songid_exists_flag ):
        to_be_added = itemset.copy()
        if possible_songids[0] in itemset:
            to_be_added.remove(possible_songids[0])
        if possible_songids[1] in itemset:
            to_be_added.remove(possible_songids[1])
        if possible_songids[2] in itemset:
            to_be_added.remove(possible_songids[2])
        for song in to_be_added:
            if 'L' in song:
                if song not in recommendations_L:
                    recommendations_L.append(song)
            elif 'M' in song:
                if song not in recommendations_M:
                    recommendations_M.append(song)
            elif 'H' in song:
                if song not in recommendations_H:
                    recommendations_H.append(song)
            
recommendations = recommendations_H + recommendations_M + recommendations_L

if(len(recommendations) == 0):
    print("We don't have song recommendations for this song from this method. Sorry!")
else:
    print("Recommendations for songid = "+str(songid) +" in descending order are : " )
    print(recommendations)
# Out:
# Recommendations for songid = 14397 in descending order are :
# ['25150H', '91177H', '217471H', '244143H', '12985H', '319911H', '357810H', '190006H', '307202H', '123630H', '266750H', '288653H', '291341H', '233632H', '54386H', '25323H', '221730H', '115274H', '52478H', '177486H', '68212H', '373947H', '281075H', '177574H', '351764H', '302247H', '311604H', '305541H', '231280H', '241705H', '192716H', '134402H', '289658H', '180413H', '333259H', '19682H', '334187H', '319788H', '97972H', '45592H', '301674H', '302369H', '115162H', '165401H', '243769H', '24825H', '261596H', '248603H', '314086H', '87433H', '177172H', '384072H', '319911M', '244143M', '91177M', '177172M', '384072M', '302247M', '54386M', '25150M', '243769M', '87433M', '123630M', '52478M', '333259M', '217471M', '288653M', '12985M', '357810M', '165401M', '192716M', '314086M', '187097M', '301674M', '24825M', '212702M', '307202M', '211334M', '2078M', '8402M', '45592M', '241705M', '266750M', '311604M', '221730M', '25323M', '231280M', '277126M', '310418M', '311262M', '243307M', '68212M', '134402M', '115274M', '207935M', '11011M', '233632M', '16220M', '319788M', '142602M', '351764M', '177486M', '334187M', '291341M', '3525M', '74558M', '212017M', '354625M', '97972M', '337625M', '292298M', '285387M', '170541M', '183796M', '19682M', '305991M', '315812M', '280827M', '232040M', '365793M', '282116M', '6449M', '62467M', '74321M', '353700M', '322843M', '195955M', '142745M', '281102M', '245936M', '307140M', '329869M', '242151M', '281075M', '86545M', '373947M', '220520M', '378274M', '167128M', '295919M', '196619M', '108137M', '57500M', '335634M', '223714M', '245012M', '90822M', '329834M', '334240M', '383719M', '251101M', '183790M', '302369M', '115162M', '38941M', '289658M', '217471L', '91177L', '357810L', '233632L', '38941L', '307140L', '54386L', '177172L', '115274L', '231280L', '302247L', '353700L', '315812L', '314086L', '242151L', '8402L', '319788L', '241705L', '142745L', '165401L', '333259L', '301674L', '211334L', '74558L', '154559L', '24825L', '52478L', '309384L', '202995L', '25150L', '288653L', '107825L', '12985L', '339774L', '170541L', '69165L', '188333L', '75497L', '259912L', '262242L', '6449L', '302369L', '261901L', '282116L', '45592L', '365793L', '6146L', '295919L', '127365L', '243769L', '73317L', '87433L', '327563L', '253868L', '277126L', '232040L', '287657L', '305541L', '28632L', '190006L', '86545L', '183796L', '83123L', '134402L', '128469L', '235145L', '340072L', '84395L', '384037L', '841L', '93787L', '117727L', '105434L', '319911L', '206288L', '293778L', '205995L', '192425L', '334240L', '2078L', '68212L', '107193L', '187097L', '305444L', '147248L', '16174L', '346138L', '122591L', '281075L', '311933L', '62467L', '237680L', '195955L', '175099L', '341506L', '74321L', '310418L', '174148L', '220520L', '343207L', '280827L', '186533L', '309958L', '235657L', '329869L', '70949L', '97972L', '13187L', '119433L', '39401L', '134909L', '266750L', '207935L', '245936L', '348629L', '302569L', '225153L', '171320L', '309748L', '137197L', '353035L', '16220L', '307202L', '46477L', '325835L', '8661L', '374516L', '50740L', '37271L', '234609L', '177574L', '138672L', '105694L', '383719L', '208383L', '289658L', '221730L', '214440L', '361372L', '196875L', '212852L', '170306L', '149371L', '292298L', '207916L', '212017L', '123630L', '225607L', '111478L', '98664L', '147082L', '280035L', '354487L', '16989L', '330392L', '250930L', '311363L', '55106L', '123457L', '245012L', '335634L', '180413L', '244143L', '252131L', '278243L', '196619L', '272664L', '136139L', '322987L', '99425L', '196087L', '157648L', '121733L', '243516L', '359476L', '315425L', '362652L', '51070L', '52176L', '177486L', '251150L', '337625L', '285387L', '341456L', '25323L', '373158L', '63245L', '218183L', '29476L', '67850L', '180706L', '3444L', '201980L', '251757L', '135204L', '197733L', '305496L', '155424L', '516L', '295651L', '305383L', '378274L', '256263L', '150684L', '359613L', '26935L', '98159L', '30643L', '242558L', '307414L', '223714L', '109807L', '167248L', '108137L', '55364L', '291341L', '329834L', ...

# %%
clean_recommendations = []
for i in range(len(recommendations)):
    if 'L' in recommendations[i]:
        clean_recommendations.append(int(recommendations[i].replace('L','')))
    elif 'M' in recommendations[i]:
        clean_recommendations.append(int(recommendations[i].replace('M','')))
    elif 'H' in recommendations[i]:
        clean_recommendations.append(int(recommendations[i].replace('H','')))
        
#clean_recommendations
