# %%
import ast
import pandas as pd
import sys
import matplotlib.pylab as plt
import timeit

# %%
collaborative_filtering_results_file_location = './Dataset/Results_collaborative_filtering.txt'
songid_mappings_file_location = './Dataset/kaggle_songs.txt'
fp_growth_itemsets_all_dataset_file_location = './Dataset/frequent_itemsets_FP_growth_all_dataset_with_HML.txt'
fp_growth_itemsets_reduced_dataset_file_location = './Dataset/frequent_itemsets_FP_growth_reduced_dataset_with_HML.txt'

# %%
#CF

songid_mappings_file = open(songid_mappings_file_location)
songid_mappings = {}
for line in songid_mappings_file:
    temp_var = line.strip().split()
    songid_mappings[temp_var[0]] = int(temp_var[1])

songid_mappings_file.close()
#songid_mappings

collaborative_filtering_results_file = open(collaborative_filtering_results_file_location)
collaborative_filtering_results_dict = {}
for line in collaborative_filtering_results_file:
    temp_results_string_songids = line.replace('{','').replace('}','').strip().split(',')
    temp_results_numeric_songids = []
    for songid in temp_results_string_songids:
        temp_results_numeric_songids.append(songid_mappings[songid.strip()])
    collaborative_filtering_results_dict[temp_results_numeric_songids[0]] = temp_results_numeric_songids[1:]
collaborative_filtering_results_file.close()

# %%
len(collaborative_filtering_results_dict)
# Out:
# 163206

# %%
#Recommendation from CF

songid = 14397
if songid in collaborative_filtering_results_dict:
    print("Recommendations for songid = "+str(songid) +" in descending order are : " )
    print(collaborative_filtering_results_dict[songid])
else:
    print("We don't have song recommendations for this song from this method. Sorry!")
# Out:
# Recommendations for songid = 14397 in descending order are :
# [86501, 46198, 223965, 344050, 36219, 150002, 280322, 304363, 263931, 237770, 173242, 118277, 125168, 215655, 176947, 325995, 55724, 176213, 136904, 150440, 58653, 67259, 327255, 381744, 108213, 289312, 241056, 46970, 364357, 166404, 354846, 158864, 117449, 29690, 160857, 127556, 325480, 29076, 63380, 180437, 180178, 381556, 373727, 53782, 371492, 40951, 227164, 45678, 191834, 79242, 128505, 44869, 173458, 20679, 353935, 305343, 8217, 356704, 241032, 73358, 116125, 317967, 82670, 378359, 272338, 101118, 59129, 94383, 343778, 268071, 320278, 290927, 294702, 323906, 254343, 61215, 318152, 198783, 226531, 90838, 113475, 194510, 6994, 105939, 132809, 44167, 196251, 45207, 57610, 86496, 265024, 384515, 133714, 156351, 256493, 44424, 297950, 283180, 164881, 263976, 379803, 383624, 364204, 278671, 18345, 131628, 266410, 161941, 27387, 103473, 164322, 248347, 255978, 204200, 180050, 261127, 111897, 270206, 374715, 274722, 120537, 103697, 150649, 374372, 381924, 256678, 56924, 335213, 207261, 338991, 62920, 114057, 96684, 96460, 364908, 54221, 221298, 276025, 180380, 352643, 336728, 221761, 374118, 307774, 285558, 12592, 50870, 92755, 244396, 94215, 121729, 94286, 13627, 50227, 166511, 373595, 180876, 346608, 277721, 276003, 324443, 97551, 236151, 156389, 162835, 339732, 365030, 343354, 234563, 188597, 137667, 50620, 111914, 78896, 9042, 42926, 291175, 262496, 120752, 1599, 207448, 105796, 214534, 374449, 27136, 28604, 372780, 116263, 339542, 279782, 308561, 39516, 70104, 284903, 230237, 300052, 128582, 312643, 212405, 208350, 319955, 299032, 94373, 226679, 151442, 57606, 154112, 120655, 268326, 355114, 299578, 78314, 36141, 237097, 126771, 272007, 61132, 112800, 237263, 262429, 124828, 260207, 113019, 123137, 53745, 289948, 3750, 14356, 355476, 125510, 187284, 272862, 172724, 32069, 254154, 135725, 250027, 4180, 69873, 57300, 55561, 27235, 260912, 339904, 352670, 206748, 305543, 195614, 169093, 258889, 44684, 158114, 170410, 336, 259223, 242405, 4803, 51733, 90911, 359230, 377296, 374680, 37296, 102118, 162950, 6372, 126996, 267745, 334431, 82594, 225752, 168747, 137780, 297626, 310249, 376784, 9513, 106147, 177286, 284670, 278695, 297946, 86143, 175796, 195467, 193727, 299803, 183346, 145482, 190892, 328, 241212, 249154, 338077, 318221, 69628, 334583, 237708, 39567, 167303, 91460, 333059, 126375, 249084, 355233, 95941, 138347, 7231, 191106, 91559, 239069, 105791, 203776, 33441, 177652, 3888, 157663, 149383, 89880, 206606, 144694, 320911, 275709, 356076, 81957, 53983, 137281, 379675, 165524, 75931, 165116, 98039, 334484, 106635, 194259, 165964, 183241, 342877, 269103, 263891, 235124, 350726, 36573, 60073, 353638, 147728, 200682, 275111, 346744, 323431, 345241, 303143, 357984, 229540, 145099, 183387, 286869, 84955, 168366, 273141, 247991, 201519, 82427, 355257, 300179, 289756, 260366, 328602, 68252, 216083, 30507, 348107, 315459, 164131, 70864, 3794, 128252, 274240, 137887, 254739, 137934, 25253, 275410, 61331, 374485, 310771, 87109, 169610, 95471, 369260, 113636, 292505, 237540, 290552, 343028, 160957, 60332, 292121, 173170, 95581, 117646, 322169, 236183, 279861, 328013, 88479, 293776, 102728, 254510, 211312, 55, 196630, 34348, 127033, 339594, 25696, 333647, 67739, 138213, 359663, 257641, 129126, 117667, 372462, 327232, 59569, 243882, 141238, 26153, 128593, 235284, 331140, 170509, 148919, 21122, 293317, 125002, 13158, 130927, 288973, 181846, 123896, 53135, 173878, 44697, 248686, 174172, 279871, 22035, 276356, 290708, 238059, 300624, 218880, 41995, 45902, 207079, 239113, 332562, 144078, 7656, 209291, 339668, 217553, 122672, 187262, 267873, 96758, 79186, 239275, 376333, 255618, 20254, 185740, 116772, 325647, 76478, 278693, 169979, 365405, 31186, 150985, 361158, 250385, 143157, 122602, 362135, 339971, 23470, 41459, 244771, 150748, 228545, 292317, 56174, 114339, 61092, 68451, 216405, 44933, 321552, 326119, 380429, 328870, 73373, 343899, 281470, 93807, 298434, 63081, 383697, 51728, 129558, 196926, 291322, 346276, 86947, 330127, 17834, 3732 ...

# %% [markdown]
# **FOR FP-GROWTH ON ALL DATASET (with HML)**

# %%
fp_growth_itemsets_all_dataset_file = open(fp_growth_itemsets_all_dataset_file_location)
fp_growth_itemsets_all_dataset = []
for line in fp_growth_itemsets_all_dataset_file:
    itemset = line.strip().replace(']','').replace('[','').replace("'",'').replace(" ",'').split(',')
    fp_growth_itemsets_all_dataset.append(itemset)
    
fp_growth_itemsets_all_dataset_file.close()

# %%
#Recommendations from FP growth

songid = 14397


possible_songids = [str(songid)+'L', str(songid)+'M', str(songid)+'H']

recommendations_L = []
recommendations_M = []
recommendations_H = []

for itemset in fp_growth_itemsets_all_dataset:
    
    songid_exists_flag = (possible_songids[0] in itemset) or (possible_songids[1] in itemset) or (possible_songids[2] in itemset)
    
    if( songid_exists_flag ):
        to_be_added = itemset.copy()
        if possible_songids[0] in itemset:
            to_be_added.remove(possible_songids[0])
        if possible_songids[1] in itemset:
            to_be_added.remove(possible_songids[1])
        if possible_songids[2] in itemset:
            to_be_added.remove(possible_songids[2])
        for song in to_be_added:
            if 'L' in song:
                if song not in recommendations_L:
                    recommendations_L.append(song)
            elif 'M' in song:
                if song not in recommendations_M:
                    recommendations_M.append(song)
            elif 'H' in song:
                if song not in recommendations_H:
                    recommendations_H.append(song)
            
recommendations = recommendations_H + recommendations_M + recommendations_L
clean_recommendations = []
for i in range(len(recommendations)):
    if 'L' in recommendations[i]:
        clean_recommendations.append(int(recommendations[i].replace('L','')))
    elif 'M' in recommendations[i]:
        clean_recommendations.append(int(recommendations[i].replace('M','')))
    elif 'H' in recommendations[i]:
        clean_recommendations.append(int(recommendations[i].replace('H','')))
        
clean_recommendations
if(len(clean_recommendations) == 0):
    print("We don't have song recommendations for this song from this method. Sorry!")
else:
    print("Recommendations for songid = "+str(songid) +" in descending order are : " )
    print(clean_recommendations)
# Out:
# Recommendations for songid = 14397 in descending order are :
# [25150, 91177, 217471, 244143, 12985, 319911, 357810, 190006, 307202, 123630, 266750, 288653, 291341, 233632, 54386, 25323, 221730, 115274, 52478, 177486, 68212, 373947, 281075, 177574, 351764, 302247, 311604, 305541, 231280, 241705, 192716, 134402, 289658, 180413, 333259, 19682, 334187, 319788, 97972, 45592, 301674, 302369, 115162, 165401, 243769, 24825, 261596, 248603, 314086, 87433, 177172, 384072, 319911, 244143, 91177, 177172, 384072, 302247, 54386, 25150, 243769, 87433, 123630, 52478, 333259, 217471, 288653, 12985, 357810, 165401, 192716, 314086, 187097, 301674, 24825, 212702, 307202, 211334, 2078, 8402, 45592, 241705, 266750, 311604, 221730, 25323, 231280, 277126, 310418, 311262, 243307, 68212, 134402, 115274, 207935, 11011, 233632, 16220, 319788, 142602, 351764, 177486, 334187, 291341, 3525, 74558, 212017, 354625, 97972, 337625, 292298, 285387, 170541, 183796, 19682, 305991, 315812, 280827, 232040, 365793, 282116, 6449, 62467, 74321, 353700, 322843, 195955, 142745, 281102, 245936, 307140, 329869, 242151, 281075, 86545, 373947, 220520, 378274, 167128, 295919, 196619, 108137, 57500, 335634, 223714, 245012, 90822, 329834, 334240, 383719, 251101, 183790, 302369, 115162, 38941, 289658, 217471, 91177, 357810, 233632, 38941, 307140, 54386, 177172, 115274, 231280, 302247, 353700, 315812, 314086, 242151, 8402, 319788, 241705, 142745, 165401, 333259, 301674, 211334, 74558, 154559, 24825, 52478, 309384, 202995, 25150, 288653, 107825, 12985, 339774, 170541, 69165, 188333, 75497, 259912, 262242, 6449, 302369, 261901, 282116, 45592, 365793, 6146, 295919, 127365, 243769, 73317, 87433, 327563, 253868, 277126, 232040, 287657, 305541, 28632, 190006, 86545, 183796, 83123, 134402, 128469, 235145, 340072, 84395, 384037, 841, 93787, 117727, 105434, 319911, 206288, 293778, 205995, 192425, 334240, 2078, 68212, 107193, 187097, 305444, 147248, 16174, 346138, 122591, 281075, 311933, 62467, 237680, 195955, 175099, 341506, 74321, 310418, 174148, 220520, 343207, 280827, 186533, 309958, 235657, 329869, 70949, 97972, 13187, 119433, 39401, 134909, 266750, 207935, 245936, 348629, 302569, 225153, 171320, 309748, 137197, 353035, 16220, 307202, 46477, 325835, 8661, 374516, 50740, 37271, 234609, 177574, 138672, 105694, 383719, 208383, 289658, 221730, 214440, 361372, 196875, 212852, 170306, 149371, 292298, 207916, 212017, 123630, 225607, 111478, 98664, 147082, 280035, 354487, 16989, 330392, 250930, 311363, 55106, 123457, 245012, 335634, 180413, 244143, 252131, 278243, 196619, 272664, 136139, 322987, 99425, 196087, 157648, 121733, 243516, 359476, 315425, 362652, 51070, 52176, 177486, 251150, 337625, 285387, 341456, 25323, 373158, 63245, 218183, 29476, 67850, 180706, 3444, 201980, 251757, 135204, 197733, 305496, 155424, 516, 295651, 305383, 378274, 256263, 150684, 359613, 26935, 98159, 30643, 242558, 307414, 223714, 109807, 167248, 108137, 55364, 291341, 329834, 253432, 351922, 35337, 89424, 34948, 231613, 160694, 138265, 231556, 71476, 16177, 186863, 128247, 97555, 220731, 349184, 166650, 62960, 95103, 273887, 349271, 82581, 287391, 344876, 257947, 222088, 301690, 68729, 364125, 54368, 292369, 290375, 130077, 385556, 212753, 297177, 2242, 190270, 49469, 273894, 345265, 311262, 3525, 354625, 183790, 239858, 257219, 66513, 361137, 299971, 91108, 158075, 100897, 204139, 278861, 220770, 263887, 303749, 247570, 218440, 284727, 270991, 305244, 145952, 161507, 332771, 305804, 362235, 251010, 335200, 374972, 27676, 214742, 6982, 239018, 229348, 129495, 198994, 132813, 115162, 362714, 243307, 65358, 126831, 301822, 110669, 98202, 249949, 203938, 293768, 215027, 337939, 63735, 351678, 143064, 68638, 116596, 289214, 209803, 56866, 7537, 252651, 295286, 132198, 33283, 102500, 127140, 57948, 156046, 64001, 288712, 274986, 347520, 193512, 307098, 300918, 34876, 245546, 309892, 296731, 236352, 66795, 361981, 348798, 258100, 244189, 276631, 191003, 73942, 15003, 337785, 341964, 31260, 318454, 92566, 76143, 91773, 228613, 172483, 363559, 351241, 225221, 142382, 285257, 29156 ...

# %% [markdown]
# **FOR FP-GROWTH ON ALL DATASET (with HML)**

# %%
fp_growth_itemsets_reduced_dataset_file = open(fp_growth_itemsets_reduced_dataset_file_location)
fp_growth_itemsets_reduced_dataset = []
for line in fp_growth_itemsets_reduced_dataset_file:
    itemset = line.strip().replace(']','').replace('[','').replace("'",'').replace(" ",'').split(',')
    fp_growth_itemsets_reduced_dataset.append(itemset)
    
fp_growth_itemsets_reduced_dataset_file.close()

# %%
#Recommendations from FP growth

songid = 14397

possible_songids = [str(songid)+'L', str(songid)+'M', str(songid)+'H']

recommendations_L = []
recommendations_M = []
recommendations_H = []

for itemset in fp_growth_itemsets_reduced_dataset:
    
    songid_exists_flag = (possible_songids[0] in itemset) or (possible_songids[1] in itemset) or (possible_songids[2] in itemset)
    
    if( songid_exists_flag ):
        to_be_added = itemset.copy()
        if possible_songids[0] in itemset:
            to_be_added.remove(possible_songids[0])
        if possible_songids[1] in itemset:
            to_be_added.remove(possible_songids[1])
        if possible_songids[2] in itemset:
            to_be_added.remove(possible_songids[2])
        for song in to_be_added:
            if 'L' in song:
                if song not in recommendations_L:
                    recommendations_L.append(song)
            elif 'M' in song:
                if song not in recommendations_M:
                    recommendations_M.append(song)
            elif 'H' in song:
                if song not in recommendations_H:
                    recommendations_H.append(song)
            
recommendations = recommendations_H + recommendations_M + recommendations_L
clean_recommendations = []
for i in range(len(recommendations)):
    if 'L' in recommendations[i]:
        clean_recommendations.append(int(recommendations[i].replace('L','')))
    elif 'M' in recommendations[i]:
        clean_recommendations.append(int(recommendations[i].replace('M','')))
    elif 'H' in recommendations[i]:
        clean_recommendations.append(int(recommendations[i].replace('H','')))
        
clean_recommendations
if(len(clean_recommendations) == 0):
    print("We don't have song recommendations for this song from this method. Sorry!")
else:
    print("Recommendations for songid = "+str(songid) +" in descending order are : " )
    print(clean_recommendations)
# Out:
# We don't have song recommendations for this song from this method. Sorry!
